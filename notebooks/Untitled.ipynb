# %%
import json
import elo
import pandas as pd
from importlib import reload

elo = reload(elo)
from elo import get_state, order_state

# %%
state = get_state()
ordered = order_state(state)

scores = pd.DataFrame([{"word": k, "score": v["initial_rating"]} for k, v in ordered.items()])
          
scores
# Out:
#              word       score
# 0    actionscript  455.800943
# 1           store  455.800943
# 2            ruby  455.800943
# 3        dawnload  455.800943
# 4         arduino  455.800943
# ..            ...         ...
# 315         board  344.199057
# 316        others  344.199057
# 317           dev  344.199057
# 318    applicable  344.199057
# 319   information  344.199057
#
# [320 rows x 2 columns]
